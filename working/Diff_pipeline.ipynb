# %%
from nipype import Node, Workflow
import nipype.interfaces.mrtrix3 as mrt3
import nipype.interfaces.mrtrix as mrt
import os
import glob 
import nibabel as nb
import matplotlib.pyplot as plt
from pathlib import Path
import shutil
import argparse
import fnmatch

# %%
os.chdir('/mnt/c/Users/calia/Documents/Scripts/Test_area/7352613/')
path = os.chdir('/mnt/c/Users/calia/Documents/Scripts/Test_area/7352613/')
path = os.getcwd()

# parser = argparse.ArgumentParser()
# parser.add_argument("--pe1", "-pe1")
# parser.add_argument("--pe2", "-pe2")
# parser.add_argument("--bvec", "-bvec", required=False)
# parser.add_argument("--bval", "-bval", required=False)
# args = parser.parse_args()

# PE_1 = args.pe1
# PE_2 = args.pe2


                
PE_1 = ('/mnt/c/Users/calia/Documents/scripts/Test_area/7352613/DICOM_DWI_LR_BIC_20140722165645_17.nii.gz')
PE_2 = ('/mnt/c/Users/calia/Documents/scripts/Test_area/7352613/DICOM_DWI_RL_BIC_20140722165645_19.nii.gz')

pe_dir_1 = ['AP', 'RL', 'SI']
pe_dir_2 = ['PA', 'LR', 'IS']

data_dir = ["orig", "mrtrix_files", "dtifit", "bedpostx"]



def files(path):
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file
            


def organize_dir(dir_name):
    if not os.path.isdir(dir_name):
        print(dir_name + " directory created, all related files will be moved here...")
        os.mkdir(dir_name)
    elif os.path.isdir(dir_name):
        print(
            dir_name
            + " directory found, moving all related outputs to this directory..."
        )


organize_dir(data_dir[0])
# Out:
# orig directory found, moving all related outputs to this directory...

# %%
ext = [".nii.gz", ".nii ", ".bvec", ".bval", ".json"]

orig_dir = os.path.join(path, "orig")

file_list = []

for file in files(path):
    if file.endswith(tuple(ext)):
        file_list.append(file)
        shutil.copy(file, orig_dir)

        

print("-----File Manifest-----")
print("")
for xx in file_list:
    print(xx)
    print("")


direction_1_string = Path(PE_1).stem.split(".")[0]
direction_2_string = Path(PE_2).stem.split(".")[0]



dir_1_list = []
dir_2_list = []
# Out:
# -----File Manifest-----
#
# DICOM_DWI_LR_BIC_20140722165645_17.bval
#
# DICOM_DWI_LR_BIC_20140722165645_17.bvec
#
# DICOM_DWI_LR_BIC_20140722165645_17.json
#
# DICOM_DWI_LR_BIC_20140722165645_17.nii.gz
#
# DICOM_DWI_RL_BIC_20140722165645_19.bval
#
# DICOM_DWI_RL_BIC_20140722165645_19.bvec
#
# DICOM_DWI_RL_BIC_20140722165645_19.json
#
# dwi_PE_1.bval
#
# dwi_PE_1.bvec
#
# dwi_PE_1.json
#
# dwi_PE_2.bval
#
# dwi_PE_2.bvec
#
# dwi_PE_2.json
#
# dwi_PE_2.nii.gz

# %%
for file in files(path):
    for pe_dir in pe_dir_1:
        if pe_dir[:] in file:
            dir_1_list.append(file)  

                

for file2 in files(path):
    for pe_dir in pe_dir_2:
        if pe_dir[:] in file2:
            dir_2_list.append(file2)
print(dir_1_list)
print(dir_2_list)
# Out:
# ['DICOM_DWI_RL_BIC_20140722165645_19.bval', 'DICOM_DWI_RL_BIC_20140722165645_19.bvec', 'DICOM_DWI_RL_BIC_20140722165645_19.json']
# ['DICOM_DWI_LR_BIC_20140722165645_17.bval', 'DICOM_DWI_LR_BIC_20140722165645_17.bvec', 'DICOM_DWI_LR_BIC_20140722165645_17.json', 'DICOM_DWI_LR_BIC_20140722165645_17.nii.gz']

# %%
# if filename contains 'AP', 'RL', 'SI'....

for a in dir_1_list:
    if a.endswith(".nii.gz"):
        os.rename(a, "dwi_PE_1.nii.gz")
    elif a.endswith(".nii"):
        os.rename(a, "dwi_PE_1.nii")
    elif a.endswith(".bvec"):
        os.rename(a, "dwi_PE_1.bvec")
    elif a.endswith(".bval"):
        os.rename(a, "dwi_PE_1.bval")
    elif a.endswith(".json"):
        os.rename(a, "dwi_PE_1.json")

# # IMPORTANT - All files belonging to a dwi volume MUST CONTAIN the same basename (i.e., dwi.nii, dwi.bvec, dwi.bval, dwi.json)

for t in dir_2_list:
    if t.endswith(".nii.gz"):
        os.rename(t, "dwi_PE_2.nii.gz")
    elif t.endswith(".nii"):
        os.rename(t, "dwi_PE_2.nii")
    elif t.endswith(".bvec"):
        os.rename(t, "dwi_PE_2.bvec")
    elif t.endswith(".bval"):
        os.rename(t, "dwi_PE_2.bval")
    elif t.endswith(".json"):
        os.rename(t, "dwi_PE_2.json")

# %%
def mrzip(in_file):
    if in_file.endswith('.nii'):
        mrconvert = mrt3.MRConvert()
        mrconvert.inputs.in_file = in_file
        mrconvert.inputs.out_file = in_file + '.gz'
        mrconvert.inputs.args = '-force'
        mrconvert.run()
        return

    

mrzip('dwi_PE_1.nii')
mrzip('dwi_PE_2.nii')
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /tmp/ipykernel_689/3837955757.py in <module>
#      10
#      11
# ---> 12 mrzip('dwi_PE_1.nii')
#      13 mrzip('dwi_PE_2.nii')
#
# /tmp/ipykernel_689/3837955757.py in mrzip(in_file)
#       2     if in_file.endswith('.nii'):
#       3         mrconvert = mrt3.MRConvert()
# ----> 4         mrconvert.inputs.in_file = in_file
#       5         mrconvert.inputs.out_file = in_file + '.gz'
#       6         mrconvert.inputs.args = '-force'
#
# ~/miniconda3/lib/python3.9/site-packages/nipype/interfaces/base/traits_extension.py in validate(self, objekt, name, value, return_pathlike)
#     328     def validate(self, objekt, name, value, return_pathlike=False):
#     329         """Validate a value change."""
# --> 330         value = super(File, self).validate(objekt, name, value, return_pathlike=True)
#     331         if self._exts:
#     332             fname = value.name
#
# ~/miniconda3/lib/python3.9/site-packages/nipype/interfaces/base/traits_extension.py in validate(self, objekt, name, value, return_pathlike)
#     133         if self.exists:
#     134             if not value.exists():
# --> 135                 self.error(objekt, name, str(value))
#     136
#     137             if self._is_file and not value.is_file():
#
# ~/miniconda3/lib/python3.9/site-packages/traits/base_trait_handler.py in error(self, object, name, value)
#      72             The proposed new value for the attribute.
#      73         """
# ---> 74         raise TraitError(
#      75             object, name, self.full_info(object, name, value), value
#      76         )
#
# TraitError: The 'in_file' trait of a MRConvertInputSpec instance must be a pathlike object or string representing an existing file, but a value of 'dwi_PE_1.nii' <class 'str'> was specified.

# %%
mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "dwi_PE_1.nii.gz"
mrconvert.inputs.out_file = "dwi_PE_1.mif"
mrconvert.inputs.args = (
    "-fslgrad dwi_PE_1.bvec dwi_PE_1.bval -json_import dwi_PE_1.json -force"
)
mrconvert.run()

mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "dwi_PE_2.nii.gz"
mrconvert.inputs.out_file = "dwi_PE_2.mif"
mrconvert.inputs.args = (
    "-fslgrad dwi_PE_2.bvec dwi_PE_2.bval -json_import dwi_PE_2.json -force"
)
mrconvert.run()

mrcat = mrt3.MRCat()
mrcat.inputs.in_files = ["dwi_PE_1.mif", "dwi_PE_2.mif"]
mrcat.inputs.out_file = "dwi_merged_PE.mif"
mrcat.run()

mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "dwi_merged_PE.mif"
mrconvert.inputs.out_file = "dwi_merged_PE.mif"
mrconvert.inputs.args = (
    "-export_pe_eddy index.txt config.txt -export_grad_fsl bvecs bvals -force"
)
mrconvert.run()


dwidenoise = mrt3.DWIDenoise()
dwidenoise.inputs.in_file = "dwi_merged_PE.mif"
dwidenoise.inputs.out_file = "denoised_merged_dwi.mif"
dwidenoise.inputs.noise = "noise.mif"
dwidenoise.inputs.args = "-extent 5 -force"
dwidenoise.run()

dwiextract = mrt3.DWIExtract()
dwiextract.inputs.in_file = "denoised_merged_dwi.mif"
dwiextract.inputs.bzero = True
dwiextract.inputs.out_file = "b0_vols.mif"
dwiextract.inputs.grad_fsl = ("bvecs", "bvals")
dwiextract.run()

preproc = mrt3.DWIPreproc()
preproc.inputs.in_file = "denoised_merged_dwi.mif"
preproc.inputs.rpe_options = "all"
preproc.inputs.out_file = "preproc.mif"
preproc.inputs.eddy_options = (
    "--slm=linear --cnr_maps"  # linear second level model and replace outliers
)
preproc.inputs.args = "-nthreads 5 -eddyqc_all eddy -force"
preproc.inputs.export_grad_mrtrix = True
preproc.inputs.pe_dir = "AP"
preproc.run()

mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "preproc.mif"
mrconvert.inputs.out_file = "preproc.mif"
mrconvert.inputs.args = "-export_grad_fsl eddy_bvecs eddy_bvals -force"
mrconvert.run()

mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "dwi_merged_PE.mif"
mrconvert.inputs.out_file = "dwi_merged_PE.nii.gz"
mrconvert.run()

mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "noise.mif"
mrconvert.inputs.out_file = "noise.nii.gz"
mrconvert.run()

# Compute residuals by subtracting noise from raw image

# %%
maths = fsl.ImageMaths()
maths.inputs.in_file = "dwi_merged_PE.nii.gz"
maths.inputs.args = "-sub noise.nii.gz"
maths.inputs.out_file = "residuals.nii.gz"
maths.run()

dwiextract = mrt3.DWIExtract()
dwiextract.inputs.in_file = "preproc.mif"
dwiextract.inputs.bzero = True
dwiextract.inputs.out_file = "preproc_b0_vols.mif"
dwiextract.inputs.grad_fsl = ("eddy_bvecs", "eddy_bvals")
dwiextract.run()

mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "preproc_b0_vols.mif"
mrconvert.inputs.out_file = "preproc_b0_vols.nii.gz"
mrconvert.run()


mrconvert = mrt3.MRConvert()
mrconvert.inputs.in_file = "preproc.mif"
mrconvert.inputs.out_file = "preproc.nii.gz"
mrconvert.run()

bet = fsl.BET()
bet.inputs.in_file = "preproc_b0_vols.nii.gz"
bet.inputs.mask = True
bet.inputs.frac = 0.15
bet.run()

dti = fsl.DTIFit()
dti.inputs.dwi = "preproc.nii.gz"
dti.inputs.bvecs = "eddy_bvecs"
dti.inputs.bvals = "eddy_bvals"
dti.inputs.base_name = "dtifit"
dti.inputs.mask = "preproc_b0_vols_brain_mask.nii.gz"
dti.run()

mrtrix_dir = os.path.join(path, "mrtrix_files")
# Out:
# 220219-17:59:24,604 nipype.interface INFO:
# dwiextract: [100%] extracting volumes[0K
# 220219-17:59:24,848 nipype.interface INFO:
# mrconvert: [100%] copying from "preproc_b0_vols.mif" to "preproc_b0_vols.nii.gz"
# 220219-17:59:24,972 nipype.interface INFO:
# mrconvert: [100%] compressing image "preproc_b0_vols.nii.gz"[0K
# 220219-17:59:25,457 nipype.interface INFO:
# mrconvert: [100%] copying from "preproc.mif" to "preproc.nii.gz"[0K
# 220219-17:59:29,435 nipype.interface INFO:
# mrconvert: [100%] compressing image "preproc.nii.gz"[0K
# 220219-17:59:31,657 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.657281:0 128 0 128 0 72
# 220219-17:59:31,757 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.757392:0 slices processed
# 220219-17:59:31,762 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.762419:1 slices processed
# 220219-17:59:31,766 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.766854:2 slices processed
# 220219-17:59:31,771 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.771358:3 slices processed
# 220219-17:59:31,776 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.776173:4 slices processed
# 220219-17:59:31,782 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.782256:5 slices processed
# 220219-17:59:31,788 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.787983:6 slices processed
# 220219-17:59:31,794 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.794482:7 slices processed
# 220219-17:59:31,802 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.802169:8 slices processed
# 220219-17:59:31,809 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.809922:9 slices processed
# 220219-17:59:31,818 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.818666:10 slices processed
# 220219-17:59:31,828 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.828059:11 slices processed
# 220219-17:59:31,838 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.837969:12 slices processed
# 220219-17:59:31,848 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.848708:13 slices processed
# 220219-17:59:31,860 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.860060:14 slices processed
# 220219-17:59:31,871 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.871589:15 slices processed
# 220219-17:59:31,883 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.883691:16 slices processed
# 220219-17:59:31,895 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.895959:17 slices processed
# 220219-17:59:31,908 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.908807:18 slices processed
# 220219-17:59:31,922 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.922211:19 slices processed
# 220219-17:59:31,936 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.936137:20 slices processed
# 220219-17:59:31,950 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.950349:21 slices processed
# 220219-17:59:31,964 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.964790:22 slices processed
# 220219-17:59:31,980 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.980087:23 slices processed
# 220219-17:59:31,997 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:31.997454:24 slices processed
# 220219-17:59:32,14 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.014533:25 slices processed
# 220219-17:59:32,32 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.032794:26 slices processed
# 220219-17:59:32,49 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.049799:27 slices processed
# 220219-17:59:32,66 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.066854:28 slices processed
# 220219-17:59:32,83 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.083397:29 slices processed
# 220219-17:59:32,100 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.099974:30 slices processed
# 220219-17:59:32,117 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.117223:31 slices processed
# 220219-17:59:32,134 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.134246:32 slices processed
# 220219-17:59:32,152 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.152161:33 slices processed
# 220219-17:59:32,168 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.168767:34 slices processed
# 220219-17:59:32,185 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.185926:35 slices processed
# 220219-17:59:32,203 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.203201:36 slices processed
# 220219-17:59:32,220 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.220054:37 slices processed
# 220219-17:59:32,237 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.237138:38 slices processed
# 220219-17:59:32,253 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.253779:39 slices processed
# 220219-17:59:32,270 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.270124:40 slices processed
# 220219-17:59:32,286 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.286034:41 slices processed
# 220219-17:59:32,301 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.301646:42 slices processed
# 220219-17:59:32,317 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.317084:43 slices processed
# 220219-17:59:32,332 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.332630:44 slices processed
# 220219-17:59:32,347 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.347856:45 slices processed
# 220219-17:59:32,363 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.363672:46 slices processed
# 220219-17:59:32,381 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.381425:47 slices processed
# 220219-17:59:32,396 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.396323:48 slices processed
# 220219-17:59:32,410 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.410091:49 slices processed
# 220219-17:59:32,422 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.422921:50 slices processed
# 220219-17:59:32,435 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.435214:51 slices processed
# 220219-17:59:32,446 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.446843:52 slices processed
# 220219-17:59:32,457 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.457719:53 slices processed
# 220219-17:59:32,467 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.467776:54 slices processed
# 220219-17:59:32,477 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.477406:55 slices processed
# 220219-17:59:32,486 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.486211:56 slices processed
# 220219-17:59:32,494 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.494105:57 slices processed
# 220219-17:59:32,501 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.501713:58 slices processed
# 220219-17:59:32,508 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.508175:59 slices processed
# 220219-17:59:32,513 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.513736:60 slices processed
# 220219-17:59:32,518 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.518632:61 slices processed
# 220219-17:59:32,523 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.523007:62 slices processed
# 220219-17:59:32,526 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.526765:63 slices processed
# 220219-17:59:32,529 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.529324:64 slices processed
# 220219-17:59:32,531 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.531113:65 slices processed
# 220219-17:59:32,531 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.531890:66 slices processed
# 220219-17:59:32,532 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.532483:67 slices processed
# 220219-17:59:32,533 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.532483:68 slices processed
# 220219-17:59:32,533 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.532483:69 slices processed
# 220219-17:59:32,533 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.532483:70 slices processed
# 220219-17:59:32,534 nipype.interface INFO:
# 	 stdout 2022-02-19T17:59:32.532483:71 slices processed

# %%
organize_dir(data_dir[1])
# Out:
# mrtrix_files directory found, moving all related outputs to this directory...
# bedpostx directory created, all related files will be moved here...

# %%
bedpost_path = os.path.join(path, 'bedpostx')


bedpost_files = ['eddy_bvecs', 'eddy_bvals', 'preproc.nii.gz', 'preproc_b0_vols_brain_mask.nii.gz']


for ii in files(path):
    if fnmatch.fnmatch(ii, bedpost_files[0]):
        ii = os.path.join(path, ii)
        shutil.copy(ii, bedpost_path)
    elif fnmatch.fnmatch(ii, bedpost_files[1]):
        ii = os.path.join(path, ii)
        shutil.copy(ii, bedpost_path)
    elif fnmatch.fnmatch(ii, bedpost_files[2]):
        ii = os.path.join(path, ii)
        shutil.copy(ii, bedpost_path)
    elif fnmatch.fnmatch(ii, bedpost_files[3]):
        ii = os.path.join(path, ii)
        shutil.copy(ii, bedpost_path)        

        
os.chdir(bedpost_path)
os.rename('eddy_bvecs', 'bvecs')
os.rename('eddy_bvals', 'bvals')
os.rename('preproc.nii.gz', 'diffusion.nii')  
os.rename('preproc_b0_vols_brain_mask.nii.gz', 'mask.nii')

# %%
for s in files(path):
    if s.endswith(".mif"):
        b = os.path.join(path, s)
        c = os.path.join(mrtrix_dir, s)
        os.replace(b, c)


dti_fit_dir = os.path.join(path, "dtifit")

organize_dir(data_dir[2])

for o in files(path):
    if o.startswith("dtifit"):
        q = os.path.join(path, o)
        y = os.path.join(dti_fit_dir, o)
        os.replace(q, y)

organize_dir(data_dir[3])
# Out:
# dtifit directory found, moving all related outputs to this directory...
# bedpostx directory created, all related files will be moved here...
